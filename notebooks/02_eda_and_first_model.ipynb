# %% [markdown]
# # Preliminary EDA + First model

# %%
import pandas as pd
import numpy as np

# %%
df =  pd.read_csv("../data/version_01/pl_2019_2024_5gw.csv", index_col=0)

# %%
df.head(3)
# Out:
#          Date   Time     HomeTeam          AwayTeam  FTHG  FTAG FTR  \
# 0  09/08/2019  20:00    Liverpool           Norwich     4     1   H
# 1  10/08/2019  12:30     West Ham          Man City     0     5   A
# 2  10/08/2019  15:00  Bournemouth  Sheffield United     1     1   D
#
#    win_rate_home  loss_rate_home  goals_scored_home  goals_conceded_home  \
# 0            NaN             NaN                NaN                  NaN
# 1            NaN             NaN                NaN                  NaN
# 2            NaN             NaN                NaN                  NaN
#
#    win_rate_away  loss_rate_away  goals_scored_away  goals_conceded_away
# 0            NaN             NaN                NaN                  NaN
# 1            NaN             NaN                NaN                  NaN
# 2            NaN             NaN                NaN                  NaN

# %% [markdown]
# Drop first 40 rows to remove nans and matches with few games in the analysis window.

# %%
df = df.iloc[40:]

# %%
df
# Out:
#             Date   Time          HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 40    14/09/2019  12:30         Liverpool       Newcastle     3     1   H
# 41    14/09/2019  15:00          Brighton         Burnley     1     1   D
# 42    14/09/2019  15:00        Man United       Leicester     1     0   H
# 43    14/09/2019  15:00  Sheffield United     Southampton     0     1   A
# 44    14/09/2019  15:00         Tottenham  Crystal Palace     4     0   H
# ...          ...    ...               ...             ...   ...   ...  ..
# 1718  12/01/2024  19:45           Burnley           Luton     1     1   D
# 1719  13/01/2024  12:30           Chelsea          Fulham     1     0   H
# 1720  13/01/2024  17:30         Newcastle        Man City     2     3   A
# 1721  14/01/2024  14:00           Everton     Aston Villa     0     0   D
# 1722  14/01/2024  16:30        Man United       Tottenham     2     2   D
#
#       win_rate_home  loss_rate_home  goals_scored_home  goals_conceded_home  \
# ...
